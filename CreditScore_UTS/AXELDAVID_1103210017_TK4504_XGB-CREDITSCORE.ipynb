# %% [markdown]
# # Mid Term Task - Machine Learning Class

# %% [markdown]
# Name                    : Axel David<br>
# NIM                     : 1103210017<br>
# Class                   : TK-45-04<br>
# Tools                   : Jupyter Notebook<br>
# Dataset                 : [Credit score classification](https://www.kaggle.com/datasets/parisrohan/credit-score-classification)<br>
# Chat-GPT Documentation  :

# %% [markdown]
# ### Problem Statement
# Imagine working as a data scientist in a global finance company. Over the years, the company has collected basic bank details and gathered a lot of credit-related information. The management wants to build an intelligent system to segregate the people into credit score brackets to reduce the manual efforts.
#
# ### Task Goal
# Given a person's credit-related information.
# Build machine learning models that can classify the credit score with >95% accuracy using Orange and Python
# (1 model minimum)

# %% [markdown]
# # ===============================

# %% [markdown]
# ## Programs

# %% [markdown]
# ### Import Dataset

# %%
# Downloading the Dataset using Kaggle API
# !kaggle datasets download -d parisrohan/credit-score-classification
# Out:
# Dataset URL: https://www.kaggle.com/datasets/parisrohan/credit-score-classification
# License(s): CC0-1.0
# credit-score-classification.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# Unzipping the Dataset
import zipfile

with zipfile.ZipFile("credit-score-classification.zip", 'r') as zip_ref:
    zip_ref.extractall("Dataset")

print("File unzipped successfully!")
# Out:
# File unzipped successfully!

# %% [markdown]
# ### Dataset Information

# %% [markdown]
# #### Train Data

# %%
import pandas as pd

# Read CSV File
train_df = pd.read_csv(r'Dataset\train.csv')
# Show Information
train_df.info()
# Show Head
train_df.head()
# Show Tail
train_df.tail()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   ID                        100000 non-null  object
#  1   Customer_ID               100000 non-null  object
#  2   Month                     100000 non-null  object
#  3   Name                      90015 non-null   object
#  4   Age                       100000 non-null  object
#  5   SSN                       100000 non-null  object
#  6   Occupation                100000 non-null  object
#  7   Annual_Income             100000 non-null  object
#  8   Monthly_Inhand_Salary     84998 non-null   float64
#  9   Num_Bank_Accounts         100000 non-null  int64
#  10  Num_Credit_Card           100000 non-null  int64
#  11  Interest_Rate             100000 non-null  int64
#  12  Num_of_Loan               100000 non-null  object
# ...

# %% [markdown]
# #### Test Data

# %%
# Read CSV File
test_df = pd.read_csv(r'Dataset\test.csv')
# Show Information
test_df.info()
# Show Head
test_df.head()
# Show Tail
test_df.tail()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        50000 non-null  object
#  1   Customer_ID               50000 non-null  object
#  2   Month                     50000 non-null  object
#  3   Name                      44985 non-null  object
#  4   Age                       50000 non-null  object
#  5   SSN                       50000 non-null  object
#  6   Occupation                50000 non-null  object
#  7   Annual_Income             50000 non-null  object
#  8   Monthly_Inhand_Salary     42502 non-null  float64
#  9   Num_Bank_Accounts         50000 non-null  int64
#  10  Num_Credit_Card           50000 non-null  int64
#  11  Interest_Rate             50000 non-null  int64
#  12  Num_of_Loan               50000 non-null  object
# ...

# %% [markdown]
# ### Preprocessing Data

# %% [markdown]
# #### Combining Train and Test Datasets

# %%
from sklearn.preprocessing import LabelEncoder
import numpy as np
 
# Combine train and test datasets for label encoding
combined_df = pd.concat([train_df, test_df], axis=0)

# %% [markdown]
# #### Data Formatting

# %%
# Convert month names to numerical values
month_encoder = LabelEncoder()
combined_df['Month'] = month_encoder.fit_transform(combined_df['Month'])

# Split back into train and test datasets
train_df = combined_df.iloc[:len(train_df)]
test_df = combined_df.iloc[len(train_df):].drop(columns=['Credit_Score'])  # Remove 'Credit_Score' from test_df

# %% [markdown]
# #### Remove Dupicates

# %%
# Remove duplicates
train_df = train_df.drop_duplicates()
test_df = test_df.drop_duplicates()

# %% [markdown]
# #### Negative Values

# %%
# Check for negative values and replace with NaN
numeric_columns = train_df.select_dtypes(include='number').columns
train_df[numeric_columns][train_df[numeric_columns] < 0] = np.nan
test_df[numeric_columns][test_df[numeric_columns] < 0] = np.nan
# Out:
# C:\Users\axeld\AppData\Local\Temp\ipykernel_52704\1762409266.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df[numeric_columns][train_df[numeric_columns] < 0] = np.nan
# C:\Users\axeld\AppData\Local\Temp\ipykernel_52704\1762409266.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df[numeric_columns][train_df[numeric_columns] < 0] = np.nan
# C:\Users\axeld\AppData\Local\Temp\ipykernel_52704\1762409266.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %% [markdown]
# #### Mising Values

# %%
# Impute missing values with mean/mode
train_df.fillna(train_df.mean(numeric_only=True), inplace=True)
test_df.fillna(test_df.mean(numeric_only=True), inplace=True)
train_df.fillna(train_df.mode(numeric_only=True).iloc[0], inplace=True)

# Reset index
train_df.reset_index(drop=True, inplace=True)
test_df.reset_index(drop=True, inplace=True)

# %% [markdown]
# ### Feature Engineering

# %% [markdown]
# #### <li>Scaling Numerical Features</li>

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.feature_selection import mutual_info_classif

# Assuming train_df and test_df are loaded with your datasets

# Define categorical columns excluding 'Credit_Score'
categorical_cols = train_df.select_dtypes(include=['object']).columns.drop(['Credit_Score'])

# Convert numerical values in categorical columns to strings
train_df[categorical_cols] = train_df[categorical_cols].astype(str)
test_df[categorical_cols] = test_df[categorical_cols].astype(str)

# Feature Engineering
# Scaling numerical features
scaler = StandardScaler()
numerical_cols = train_df.select_dtypes(include=['int64', 'float64']).columns
train_df[numerical_cols] = scaler.fit_transform(train_df[numerical_cols])
test_df[numerical_cols] = scaler.transform(test_df[numerical_cols])

# Encoding categorical variables
encoder = OneHotEncoder(drop='first')
encoded_train = pd.DataFrame(encoder.fit_transform(train_df[categorical_cols]).toarray())
encoded_test = pd.DataFrame(encoder.transform(test_df[categorical_cols]).toarray())

# Concatenate with original DataFrame and drop original categorical columns
train_df = pd.concat([train_df, encoded_train], axis=1)
test_df = pd.concat([test_df, encoded_test], axis=1)
train_df.drop(columns=categorical_cols, inplace=True)
test_df.drop(columns=categorical_cols, inplace=True)

# New Features (if applicable)
# For example, you could create a new feature by combining existing ones:
train_df['New_Feature'] = train_df['Feature1'] + train_df['Feature2']
test_df['New_Feature'] = test_df['Feature1'] + test_df['Feature2']

# Mutual Information Scores
# Calculate MI scores between features and target variable
mi_scores = mutual_info_classif(train_df.drop(columns=['Credit_Score']), train_df['Credit_Score'], random_state=42)
mi_scores = pd.Series(mi_scores, name="MI Scores", index=train_df.drop(columns=['Credit_Score']).columns)
mi_scores = mi_scores.sort_values(ascending=False)
print("Mutual Information Scores:")
print(mi_scores)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 12
#      10 # Convert numerical values in categorical columns to strings
#      11 train_df[categorical_cols] = train_df[categorical_cols].astype(str)
# ---> 12 test_df[categorical_cols] = test_df[categorical_cols].astype(str)
#      14 # Feature Engineering
#      15 # Scaling numerical features
#      16 scaler = StandardScaler()
#
# File c:\Users\axeld\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# ...

# %% [markdown]
# #### <li>Encoding Categorical Variables</li>

# %%
# Encoding categorical variables
# encoder = OneHotEncoder(drop='first')
# categorical_cols = train_df.select_dtypes(include=['object']).columns
# encoded_train = pd.DataFrame(encoder.fit_transform(train_df[categorical_cols]))
# encoded_test = pd.DataFrame(encoder.transform(test_df[categorical_cols]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\axeld\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\_encode.py:174, in _unique_python(values, return_inverse, return_counts)
#     172 uniques_set, missing_values = _extract_missing(uniques_set)
# --> 174 uniques = sorted(uniques_set)
#     175 uniques.extend(missing_values.to_list())
#
# TypeError: '<' not supported between instances of 'str' and 'float'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 4
#       2 encoder = OneHotEncoder(drop='first')
#       3 categorical_cols = train_df.select_dtypes(include=['object']).columns
# ----> 4 encoded_train = pd.DataFrame(encoder.fit_transform(train_df[categorical_cols]))
# ...
